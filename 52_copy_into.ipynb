# %%
# %sql
USE CATALOG workspace;
USE SCHEMA default;

# %%
# %sql
DROP TABLE IF EXISTS workspace.default.courses;

# %%
# %sql
-- Schritt 1: Leere Tabelle im Unity Catalog anlegen
CREATE TABLE workspace.default.courses (
  course_id BIGINT, 
  title STRING,
  instructor STRING,
  category STRING,
  price BIGINT 
) USING DELTA;

# %%
# %sql
-- Schritt 2: Daten laden
COPY INTO workspace.default.courses
FROM '/Volumes/workspace/default/volume/courses.json'
FILEFORMAT = JSON
FORMAT_OPTIONS ('inferSchema' = 'true') -- Spark versucht die Datentypen aus dem JSON zu lesen
COPY_OPTIONS ('mergeSchema' = 'true'); -- Erlaubt neue Spalten, falls das JSON wächst
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th><th>num_skipped_corrupt_files</th></tr></thead><tbody><tr><td>3</td><td>3</td><td>0</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM workspace.default.courses
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>course_id</th><th>title</th><th>instructor</th><th>category</th><th>price</th></tr></thead><tbody><tr><td>101</td><td>Data Engineering</td><td>Dr. Smith</td><td>Technology</td><td>850</td></tr><tr><td>102</td><td>Machine Learning</td><td>Dr. Lee</td><td>AI</td><td>1200</td></tr><tr><td>103</td><td>Ethics in AI</td><td>Dr. Kim</td><td>Philosophy</td><td>600</td></tr></tbody></table></div>

# %% [markdown]
#  #Aufräumen

# %%
# %sql
DROP TABLE IF EXISTS workspace.default.courses;
