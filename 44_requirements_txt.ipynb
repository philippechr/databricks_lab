# %% [markdown]
# Bestehende Library-Versionen abfragen

# %%
import pandas as pd
import numpy as np
import sklearn

# %%
import importlib

for pkg in ["pandas", "numpy", "sklearn"]:
    m = importlib.import_module(pkg.replace("-", ""))
    print(f"{pkg}: {m.__version__}")
# Out:
# pandas: 2.2.3
# numpy: 2.1.3
# sklearn: 1.6.1

# %% [markdown]
# Spezifische Library-Versionen installieren

# %%
# %pip install -r /Volumes/workspace/default/volume/requirements.txt
# Out:
# Collecting pandas==2.2.2 (from -r /Volumes/workspace/default/volume/requirements.txt (line 2))
#   Downloading pandas-2.2.2-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (19 kB)
# Collecting numpy==1.26.4 (from -r /Volumes/workspace/default/volume/requirements.txt (line 3))
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (62 kB)
# Collecting scikit-learn==1.4.2 (from -r /Volumes/workspace/default/volume/requirements.txt (line 7))
#   Downloading scikit_learn-1.4.2-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (11 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /databricks/python3/lib/python3.12/site-packages (from pandas==2.2.2->-r /Volumes/workspace/default/volume/requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.12/site-packages (from pandas==2.2.2->-r /Volumes/workspace/default/volume/requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /databricks/python3/lib/python3.12/site-packages (from pandas==2.2.2->-r /Volumes/workspace/default/volume/requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: scipy>=1.6.0 in /databricks/python3/lib/python3.12/site-packages (from scikit-learn==1.4.2->-r /Volumes/workspace/default/volume/requirements.txt (line 7)) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in /databricks/python3/lib/python3.12/site-packages (from scikit-learn==1.4.2->-r /Volumes/workspace/default/volume/requirements.txt (line 7)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.12/site-packages (from scikit-learn==1.4.2->-r /Volumes/workspace/default/volume/requirements.txt (line 7)) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas==2.2.2->-r /Volumes/workspace/default/volume/requirements.txt (line 2)) (1.16.0)
# Downloading pandas-2.2.2-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (15.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 29.4 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (13.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 89.1 MB/s eta 0:00:00
# Downloading scikit_learn-1.4.2-cp312-cp312-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (11.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 127.5 MB/s eta 0:00:00
# Installing collected packages: numpy, pandas, scikit-learn
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Not uninstalling numpy at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-16796ada-441f-475a-ba8f-df8daefd7b0c
#     Can't uninstall 'numpy'. No files were found to uninstall.
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Not uninstalling pandas at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-16796ada-441f-475a-ba8f-df8daefd7b0c
#     Can't uninstall 'pandas'. No files were found to uninstall.
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Not uninstalling scikit-learn at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-16796ada-441f-475a-ba8f-df8daefd7b0c
#     Can't uninstall 'scikit-learn'. No files were found to uninstall.
# Successfully installed numpy-1.26.4 pandas-2.2.2 scikit-learn-1.4.2
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# NEUE Session Starten: Cluster wählen - "New session"

# %%
import pandas as pd
import numpy as np
import sklearn

print(pd.__version__)
print(np.__version__)
print(sklearn.__version__)
# Out:
# 2.2.2
# 1.26.4
# 1.4.2
