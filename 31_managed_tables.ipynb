-- %% [markdown]
-- Neues Schema erstellen

-- %%
%sql
CREATE SCHEMA new_default

-- %% [markdown]
-- Catalog und Schema wählen

-- %%
%sql
USE CATALOG workspace;
USE SCHEMA new_default;

-- %% [markdown]
-- Tabelle erstellen und abfüllen

-- %%
%sql
CREATE TABLE managed_default
(country STRING, code STRING, dial_code STRING) USING DELTA;


INSERT INTO managed_default
VALUES ('France', 'FR', '+33'),
('Spain',  'ES', '+34');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>2</td><td>2</td></tr></tbody></table></div>

-- %% [markdown]
-- Metadaten explorieren

-- %%
DESCRIBE DETAIL managed_default;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>clusteringColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th><th>tableFeatures</th><th>statistics</th><th>clusterByAuto</th></tr></thead><tbody><tr><td>delta</td><td>8f92c664-e4d3-419b-b7ae-c71220275e4e</td><td>workspace.new_default.managed_default</td><td>null</td><td></td><td>2025-12-08T12:32:01.510Z</td><td>2025-12-08T12:32:04.000Z</td><td>List()</td><td>List()</td><td>1</td><td>1032</td><td>Map(delta.parquet.compression.codec -> zstd, delta.enableDeletionVectors -> true, delta.writePartitionColumnsToParquet -> true, delta.enableRowTracking -> true, delta.rowTracking.materializedRowCommitVersionColumnName -> _row-commit-version-col-2efa921c-6eb8-48d1-92f1-d2bd3a21545a, delta.rowTracking.materializedRowIdColumnName -> _row-id-col-303bd59c-6f96-4d3f-8cdf-812da2e62794)</td><td>3</td><td>7</td><td>List(appendOnly, deletionVectors, domainMetadata, invariants, rowTracking)</td><td>Map(numRowsDeletedByDeletionVectors -> 0, numDeletionVectors -> 0)</td><td>false</td></tr></tbody></table></div>

-- %%
%sql
DESCRIBE EXTENDED managed_default
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>country</td><td>string</td><td>null</td></tr><tr><td>code</td><td>string</td><td>null</td></tr><tr><td>dial_code</td><td>string</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>country, code, dial_code</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>workspace</td><td></td></tr><tr><td>Database</td><td>new_default</td><td></td></tr><tr><td>Table</td><td>managed_default</td><td></td></tr><tr><td>Created Time</td><td>Mon Dec 08 12:32:02 UTC 2025</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark </td><td></td></tr><tr><td>Statistics</td><td>1032 bytes, 2 rows</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Location</td><td></td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>philippe.christen@fhnw.ch</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Predictive Optimization</td><td>ENABLE (inherited from METASTORE metastore_aws_us_east_2)</td><td></td></tr><tr><td>Table Properties</td><td>[delta.enableDeletionVectors=true,delta.enableRowTracking=true,delta.feature.appendOnly=supported,delta.feature.deletionVectors=supported,delta.feature.domainMetadata=supported,delta.feature.invariants=supported,delta.feature.rowTracking=supported,delta.minReaderVersion=3,delta.minWriterVersion=7,delta.parquet.compression.codec=zstd,delta.rowTracking.materializedRowCommitVersionColumnName=_row-commit-version-col-2efa921c-6eb8-48d1-92f1-d2bd3a21545a,delta.rowTracking.materializedRowIdColumnName=_row-id-col-303bd59c-6f96-4d3f-8cdf-812da2e62794,delta.writePartitionColumnsToParquet=true]</td><td></td></tr></tbody></table></div>

-- %% [markdown]
-- Tabelle abfragen

-- %%
%sql
SELECT  * FROM managed_default
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th><th>code</th><th>dial_code</th></tr></thead><tbody><tr><td>France</td><td>FR</td><td>+33</td></tr><tr><td>Spain</td><td>ES</td><td>+34</td></tr></tbody></table></div>
